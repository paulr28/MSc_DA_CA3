# %%
import pandas as pd
import requests
import io
from io import StringIO

# %%
url = "https://data.ny.gov/resource/f462-ka72.csv"
output_filename = "dataset_list.csv"

response = requests.get(url)

# download the file contents into a dataframe
with open(output_filename, 'wb') as f:
    f.write(response.content)
    
print("Download ready.")

# read the dataframe
df = pd.read_csv(output_filename)

print("Dataframe ready.")
# Out:
# Download ready.
# Dataframe ready.

# %%
# Describe the dataframe
df.describe(include='all')
# Out:
#         open_dataset_id                                 dataset_name_title  \
# count        132.000000                                                132
# unique              NaN                                                132
# top                 NaN  Arts For Transit - Metropolitan Transportation...
# freq                NaN                                                  1
# mean         102.765152                                                NaN
# std           84.462003                                                NaN
# min            1.000000                                                NaN
# 25%           33.750000                                                NaN
# 50%           76.500000                                                NaN
# 75%          155.250000                                                NaN
# max          271.000000                                                NaN
#
#         agency posting_frequency  \
# count      132               132
# unique      15                 7
# top     Subway           Monthly
# freq        37                60
# mean       NaN               NaN
# std        NaN               NaN
# min        NaN               NaN
# 25%        NaN               NaN
# 50%        NaN               NaN
# 75%        NaN               NaN
# max        NaN               NaN
#
#                                               description     status  \
# count                                                 127        132
# unique                                                100          4
# top     Contains information on subway entry/exit regi...  Published
# freq                                                    9         78
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#        plan_submission_date                          nys_url  \
# count                   132                               91
# unique                    9                               91
# top                Complete  https://data.ny.gov/d/4y8j-9pkd
# freq                     78                                1
# mean                    NaN                              NaN
# std                     NaN                              NaN
# min                     NaN                              NaN
# 25%                     NaN                              NaN
# 50%                     NaN                              NaN
# 75%                     NaN                              NaN
# max                     NaN                              NaN
#
#                        catalog_category  \
# count                               130
# unique                               11
# top     1. Operational metrics and data
# freq                                 50
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# max                                 NaN
#
#                                plan_submission_date_notes
# count                                                  12
# unique                                                  8
# top     Dataset successfully published in Q2 2023. Mul...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
# Show the unique values for the dataset_name_title column, when the status column contains teh value "Published"
df[df['status'] == 'Published']['dataset_name_title'].unique()
# Out:
# array(['Arts For Transit - Metropolitan Transportation Authority (MTA) Permanent Art Catalogue',
#        'E-ZPass Retailers Locations',
#        'Eye On The Future - Metropolitan Transportation Authority (MTA) Contract Solicitations',
#        'Hourly Traffic on Metropolitan Transportation Authority (MTA) Bridges and Tunnels: Beginning 2010',
#        'MTA Customer Feedback Data: Beginning 2014',
#        'MTA Wi-Fi Locations', 'Turnstile Usage Data: 2014',
#        'Turnstile Usage Data: 2015', 'Turnstile Usage Data: 2016',
#        'Turnstile Usage Data: 2017', 'Turnstile Usage Data: 2018',
#        'Turnstile Usage Data: 2019', 'Turnstile Usage Data: 2020',
#        'Turnstile Usage Data: 2021', 'MTA Subway and Bus Vandalism',
#        'Turnstile Usage Data: 2022',
#        'MTA General Transit Feed Specification (GTFS) Static Data',
#        'MTA LIRR Lost Time Rates: Beginning 2019',
#        'MTA Subway Major Incidents: Beginning 2015',
#        'MTA LIRR Service Reliability: Beginning 2015',
#        'MTA Bus Mean Distance Between Failures: Beginning 2015',
#        'MTA Subway Mean Distance Between Failures: Beginning 2015',
#        'MTA LIRR Mean Distance Between Failures: Beginning 2015',
#        'MTA Subway Service Delivered: Beginning 2015',
#        'MTA Bus Service Delivered: Beginning 2015',
#        'MTA Subway Customer Journey-Focused Metrics: Beginning 2015',
#        'MTA Bus Customer Journey-Focused Metrics: Beginning 2017',
#        'MTA Bus Speeds: Beginning 2015',
#        'MTA LIRR Service Delivered: Beginning 2019',
#        'MTA Subway Terminal On-Time Performance: Beginning 2015',
#        'MTA LIRR On-Time Performance: Beginning 2015',
#        'MTA Access-A-Ride Pickup On-Time Performance: Beginning 2016',
#        'MTA NYCT Paratransit Provider No-Shows: Beginning 2016',
#        'MTA Access-A-Ride Customer Experience: 2018 to 2020',
#        'MTA Subway Wait Assessment: Beginning 2015',
#        'MTA Bus Wait Assessment: Beginning 2017',
#        'MTA Subway Elevator and Escalator Availability: Beginning 2015',
#        'MTA LIRR Elevator and Escalator Availability: Beginning 2019',
#        'MTA Subway and Bus Reduced-Fare MetroCard Usage: Beginning 2018',
#        'MTA Daily Ridership Data: Beginning 2020',
#        'MTA Subway Accessible Station Platform Availability: Beginning 2018',
#        'MTA Subway and Bus Employee Assaults and Harassments',
#        'MTA Bus Passenger Environment Survey: 2015 to 2019',
#        'MTA Subway Car Passenger Environment Survey: 2015 to 2019',
#        'MTA Subway Station Passenger Environment Survey: 2015 to 2019',
#        'MTA LIRR Systemwide Delays: Beginning 2015',
#        'MTA LIRR Fare Collection Failure Rates: Beginning 2015',
#        'MTA LIRR Chargebacks: Beginning 2015',
#        'MTA NYCT Paratransit Max Ride Time Performance: Beginning 2018',
#        'MTA Customer Feedback Performance Metrics: Beginning 2017',
#        'MTA Monthly Ridership / Traffic Data: Beginning January 2008',
#        'MTA Bus Mean Distance Between Service Interruptions: Beginning 2015',
#        'MTA Bus Weekday Pull Out Performance: Beginning 2015',
#        'MTA Bus System Fleet Age: Beginning 2015',
#        'MTA NYCT Paratransit Registrants: Beginning 2018',
#        'MTA Subway Trains Delayed: Beginning 2020',
#        'MTA Bridges & Tunnels Monthly E-ZPass Usage Rates: Beginning 2005',
#        'MTA Bridges & Tunnels Monthly Traffic Rates: Beginning 2005',
#        'MTA Customer Engagement Statistics: Beginning May 2017',
#        'MTA Subway and Bus Lost Time Accidents',
#        'MTA Open Data Catalog and Publication Schedule',
#        'MTA Metro-North Service Delivered: Beginning January 2019',
#        'MTA Metro-North Mean Distance Between Failures: Beginning 2018',
#        'MTA Metro-North On-Time Performance: Beginning 2020',
#        'MTA Metro-North Service Reliability: Beginning 2020',
#        'Metro-North Elevator and Escalator Availability',
#        'Metro-North Lost Time Rates: Beginning 2019',
#        'MTA Subway and Bus Mask Compliance Statistics: 2020 - 2022',
#        'Metropolitan Transportation Authority (MTA) Performance Indicators per Agency: Beginning 2008',
#        'MTA Bus Customer Journey-Focused Metrics: Beginning 2020',
#        'MTA Bus Wait Assessment: Beginning 2020',
#        'MTA Bus Service Delivered: Beginning 2020',
#        'MTA Subway Service Delivered: Beginning 2020',
#        'MTA Subway Major Incidents: Beginning 2020',
#        'MTA Bus Speeds: Beginning 2020',
#        'MTA Subway Customer Journey-Focused Metrics: Beginning 2020',
#        'MTA Subway Wait Assessment: Beginning 2020',
#        'MTA Subway Terminal On-Time Performance: Beginning 2020'],
#       dtype=object)

# %%
df1 = df[df['status'] == 'Published']

# %%
# Print the count for uniuque values for the catalog_category column
df1['catalog_category'].value_counts()
# Out:
# 1. Operational metrics and data          41
# 2. System usage                          18
# 4. Safety / security                      5
# 11. Miscellaneous                         4
# 3. Accessibility                          4
# 8. Customer Feedback and Surveys          3
# 10. Assets / geographical information     2
# 9. Data feeds                             1
# Name: catalog_category, dtype: int64

# %%
# Filter the dataset where the catalog_category column contains the values "3. Accessibility", "10. Assets / geographical information", "4. Safety / security" 
df2 = df1[df1['catalog_category'].isin(["3. Accessibility", "10. Assets / geographical information", "4. Safety / security"])]

# %%
# Filter the dataset where the catalog_category column contains the values "1. Operational metrics and data"
df3 = df1[df1['catalog_category'].isin(["1. Operational metrics and data"])]

# %%
df2.describe(include = 'all')
# Out:
#         open_dataset_id           dataset_name_title  agency  \
# count         11.000000                           11      11
# unique              NaN                           11       5
# top                 NaN  E-ZPass Retailers Locations  Subway
# freq                NaN                            1       3
# mean         106.454545                          NaN     NaN
# std           99.338174                          NaN     NaN
# min            2.000000                          NaN     NaN
# 25%           27.000000                          NaN     NaN
# 50%           69.000000                          NaN     NaN
# 75%          177.500000                          NaN     NaN
# max          254.000000                          NaN     NaN
#
#        posting_frequency                                        description  \
# count                 11                                                 11
# unique                 3                                                  8
# top              Monthly  Represents the percent of the time that elevat...
# freq                   9                                                  3
# mean                 NaN                                                NaN
# std                  NaN                                                NaN
# min                  NaN                                                NaN
# 25%                  NaN                                                NaN
# 50%                  NaN                                                NaN
# 75%                  NaN                                                NaN
# max                  NaN                                                NaN
#
#            status plan_submission_date                          nys_url  \
# count          11                   11                               11
# unique          1                    1                               11
# top     Published             Complete  https://data.ny.gov/d/y59h-w6v4
# freq           11                   11                                1
# mean          NaN                  NaN                              NaN
# std           NaN                  NaN                              NaN
# min           NaN                  NaN                              NaN
# 25%           NaN                  NaN                              NaN
# 50%           NaN                  NaN                              NaN
# 75%           NaN                  NaN                              NaN
# max           NaN                  NaN                              NaN
#
#             catalog_category plan_submission_date_notes
# count                     11                          0
# unique                     3                          0
# top     4. Safety / security                        NaN
# freq                       5                        NaN
# mean                     NaN                        NaN
# std                      NaN                        NaN
# min                      NaN                        NaN
# 25%                      NaN                        NaN
# 50%                      NaN                        NaN
# 75%                      NaN                        NaN
# max                      NaN                        NaN

# %%
# Print the unique values for the catalog_category column and the corresponding dataset_name_title column
df2[['dataset_name_title','catalog_category', 'nys_url']].drop_duplicates()
# Out:
#                                     dataset_name_title  \
# 1                          E-ZPass Retailers Locations
# 10                                 MTA Wi-Fi Locations
# 20                        MTA Subway and Bus Vandalism
# 32            MTA LIRR Lost Time Rates: Beginning 2019
# 60   MTA Subway Elevator and Escalator Availability...
# 61   MTA LIRR Elevator and Escalator Availability: ...
# 79   MTA Subway Accessible Station Platform Availab...
# 80   MTA Subway and Bus Employee Assaults and Haras...
# 111             MTA Subway and Bus Lost Time Accidents
# 117    Metro-North Elevator and Escalator Availability
# 118        Metro-North Lost Time Rates: Beginning 2019
#
#                           catalog_category                          nys_url
# 1    10. Assets / geographical information  https://data.ny.gov/d/y59h-w6v4
# 10   10. Assets / geographical information  https://data.ny.gov/d/pwa9-tmie
# 20                    4. Safety / security  https://data.ny.gov/d/23fs-vfbd
# 32                    4. Safety / security  https://data.ny.gov/d/ka57-re2h
# 60                        3. Accessibility  https://data.ny.gov/d/rc78-7x78
# 61                        3. Accessibility  https://data.ny.gov/d/9hjt-526f
# 79                        3. Accessibility  https://data.ny.gov/d/thh2-syn7
# 80                    4. Safety / security  https://data.ny.gov/d/2xh4-m2qk
# 111                   4. Safety / security  https://data.ny.gov/d/8vjt-4zv4
# 117                       3. Accessibility  https://data.ny.gov/d/ax67-8386
# 118                   4. Safety / security  https://data.ny.gov/d/v7rp-a6ru

# %%
# Append '.csv?$limit=50000' to all the values in the nys_url column (To retrieve the entire dataset)
df2['nys_url'] = df2['nys_url'].apply(lambda x: x + '.csv?$limit=50000')
# Out:
# C:\Users\Paul\AppData\Local\Temp\ipykernel_32792\446028444.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['nys_url'] = df2['nys_url'].apply(lambda x: x + '.csv?$limit=50000')

# %%
# Append '.csv' to all the values in the nys_url column
df3['nys_url'] = df3['nys_url'].apply(lambda x: x + '.csv?$limit=50000')
# Out:
# C:\Users\Paul\AppData\Local\Temp\ipykernel_32792\287891110.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['nys_url'] = df3['nys_url'].apply(lambda x: x + '.csv?$limit=50000')

# %%
# replace the '/d/' with '/resource/' in the nys_url column
df2['nys_url'] = df2['nys_url'].apply(lambda x: x.replace('/d/', '/resource/'))
# Out:
# C:\Users\Paul\AppData\Local\Temp\ipykernel_32792\1295467608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['nys_url'] = df2['nys_url'].apply(lambda x: x.replace('/d/', '/resource/'))

# %%
# replace the '/d/' with '/resource/' in the nys_url column
df3['nys_url'] = df3['nys_url'].apply(lambda x: x.replace('/d/', '/resource/'))
# Out:
# C:\Users\Paul\AppData\Local\Temp\ipykernel_32792\2283690268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['nys_url'] = df3['nys_url'].apply(lambda x: x.replace('/d/', '/resource/'))

# %%
# Print the unique values for the catalog_category column and the corresponding dataset_name_title column
df2[['dataset_name_title','catalog_category', 'nys_url']].drop_duplicates()
# Out:
#                                     dataset_name_title  \
# 1                          E-ZPass Retailers Locations
# 10                                 MTA Wi-Fi Locations
# 20                        MTA Subway and Bus Vandalism
# 32            MTA LIRR Lost Time Rates: Beginning 2019
# 60   MTA Subway Elevator and Escalator Availability...
# 61   MTA LIRR Elevator and Escalator Availability: ...
# 79   MTA Subway Accessible Station Platform Availab...
# 80   MTA Subway and Bus Employee Assaults and Haras...
# 111             MTA Subway and Bus Lost Time Accidents
# 117    Metro-North Elevator and Escalator Availability
# 118        Metro-North Lost Time Rates: Beginning 2019
#
#                           catalog_category  \
# 1    10. Assets / geographical information
# 10   10. Assets / geographical information
# 20                    4. Safety / security
# 32                    4. Safety / security
# 60                        3. Accessibility
# 61                        3. Accessibility
# 79                        3. Accessibility
# 80                    4. Safety / security
# 111                   4. Safety / security
# 117                       3. Accessibility
# 118                   4. Safety / security
#
#                                                nys_url
# 1    https://data.ny.gov/resource/y59h-w6v4.csv?$li...
# 10   https://data.ny.gov/resource/pwa9-tmie.csv?$li...
# 20   https://data.ny.gov/resource/23fs-vfbd.csv?$li...
# 32   https://data.ny.gov/resource/ka57-re2h.csv?$li...
# 60   https://data.ny.gov/resource/rc78-7x78.csv?$li...
# 61   https://data.ny.gov/resource/9hjt-526f.csv?$li...
# 79   https://data.ny.gov/resource/thh2-syn7.csv?$li...
# 80   https://data.ny.gov/resource/2xh4-m2qk.csv?$li...
# 111  https://data.ny.gov/resource/8vjt-4zv4.csv?$li...
# 117  https://data.ny.gov/resource/ax67-8386.csv?$li...
# 118  https://data.ny.gov/resource/v7rp-a6ru.csv?$li...

# %%
# Print the unique values for the catalog_category column and the corresponding dataset_name_title column
df3[['dataset_name_title','catalog_category', 'nys_url']].drop_duplicates()
# Out:
#                                     dataset_name_title  \
# 34          MTA Subway Major Incidents: Beginning 2015
# 35        MTA LIRR Service Reliability: Beginning 2015
# 37   MTA Bus Mean Distance Between Failures: Beginn...
# 38   MTA Subway Mean Distance Between Failures: Beg...
# 40   MTA LIRR Mean Distance Between Failures: Begin...
# 41        MTA Subway Service Delivered: Beginning 2015
# 42           MTA Bus Service Delivered: Beginning 2015
# 43   MTA Subway Customer Journey-Focused Metrics: B...
# 44   MTA Bus Customer Journey-Focused Metrics: Begi...
# 48                      MTA Bus Speeds: Beginning 2015
# 49          MTA LIRR Service Delivered: Beginning 2019
# 50   MTA Subway Terminal On-Time Performance: Begin...
# 51        MTA LIRR On-Time Performance: Beginning 2015
# 52   MTA Access-A-Ride Pickup On-Time Performance: ...
# 53   MTA NYCT Paratransit Provider No-Shows: Beginn...
# 56   MTA Access-A-Ride Customer Experience: 2018 to...
# 58          MTA Subway Wait Assessment: Beginning 2015
# 59             MTA Bus Wait Assessment: Beginning 2017
# 81   MTA Bus Passenger Environment Survey: 2015 to ...
# 82   MTA Subway Car Passenger Environment Survey: 2...
# 83   MTA Subway Station Passenger Environment Surve...
# 84          MTA LIRR Systemwide Delays: Beginning 2015
# 88   MTA NYCT Paratransit Max Ride Time Performance...
# 91   MTA Bus Mean Distance Between Service Interrup...
# 92   MTA Bus Weekday Pull Out Performance: Beginnin...
# 93            MTA Bus System Fleet Age: Beginning 2015
# 96           MTA Subway Trains Delayed: Beginning 2020
# 113  MTA Metro-North Service Delivered: Beginning J...
# 114  MTA Metro-North Mean Distance Between Failures...
# 115  MTA Metro-North On-Time Performance: Beginning...
# 116  MTA Metro-North Service Reliability: Beginning...
# 121  Metropolitan Transportation Authority (MTA) Pe...
# 122  MTA Bus Customer Journey-Focused Metrics: Begi...
# 123            MTA Bus Wait Assessment: Beginning 2020
# 124          MTA Bus Service Delivered: Beginning 2020
# 125       MTA Subway Service Delivered: Beginning 2020
# 126         MTA Subway Major Incidents: Beginning 2020
# 127                     MTA Bus Speeds: Beginning 2020
# 128  MTA Subway Customer Journey-Focused Metrics: B...
# 129         MTA Subway Wait Assessment: Beginning 2020
# 130  MTA Subway Terminal On-Time Performance: Begin...
#
#                     catalog_category  \
# 34   1. Operational metrics and data
# 35   1. Operational metrics and data
# 37   1. Operational metrics and data
# 38   1. Operational metrics and data
# 40   1. Operational metrics and data
# 41   1. Operational metrics and data
# 42   1. Operational metrics and data
# 43   1. Operational metrics and data
# 44   1. Operational metrics and data
# 48   1. Operational metrics and data
# 49   1. Operational metrics and data
# 50   1. Operational metrics and data
# 51   1. Operational metrics and data
# 52   1. Operational metrics and data
# 53   1. Operational metrics and data
# 56   1. Operational metrics and data
# 58   1. Operational metrics and data
# 59   1. Operational metrics and data
# 81   1. Operational metrics and data
# 82   1. Operational metrics and data
# 83   1. Operational metrics and data
# 84   1. Operational metrics and data
# 88   1. Operational metrics and data
# 91   1. Operational metrics and data
# 92   1. Operational metrics and data
# 93   1. Operational metrics and data
# 96   1. Operational metrics and data
# 113  1. Operational metrics and data
# 114  1. Operational metrics and data
# 115  1. Operational metrics and data
# 116  1. Operational metrics and data
# 121  1. Operational metrics and data
# 122  1. Operational metrics and data
# 123  1. Operational metrics and data
# 124  1. Operational metrics and data
# 125  1. Operational metrics and data
# 126  1. Operational metrics and data
# 127  1. Operational metrics and data
# 128  1. Operational metrics and data
# 129  1. Operational metrics and data
# 130  1. Operational metrics and data
#
#                                                nys_url
# 34   https://data.ny.gov/resource/ereg-mcvp.csv?$li...
# 35   https://data.ny.gov/resource/x64c-i76x.csv?$li...
# 37   https://data.ny.gov/resource/7mt2-y7ip.csv?$li...
# 38   https://data.ny.gov/resource/e2qc-xgxs.csv?$li...
# 40   https://data.ny.gov/resource/cpjs-d6ua.csv?$li...
# 41   https://data.ny.gov/resource/32ch-sei3.csv?$li...
# 42   https://data.ny.gov/resource/tw28-zvtk.csv?$li...
# 43   https://data.ny.gov/resource/r7qk-6tcy.csv?$li...
# 44   https://data.ny.gov/resource/8mkn-d32t.csv?$li...
# 48   https://data.ny.gov/resource/cudb-vcni.csv?$li...
# 49   https://data.ny.gov/resource/hpua-e653.csv?$li...
# 50   https://data.ny.gov/resource/f6rf-2a3t.csv?$li...
# 51   https://data.ny.gov/resource/6kq9-5ikh.csv?$li...
# 52   https://data.ny.gov/resource/rube-svnv.csv?$li...
# 53   https://data.ny.gov/Transportation/MTA-NYCT-Pa...
# 56   https://data.ny.gov/resource/qu52-5ejz.csv?$li...
# 58   https://data.ny.gov/resource/s666-h6b7.csv?$li...
# 59   https://data.ny.gov/resource/bmix-dpzc.csv?$li...
# 81   https://data.ny.gov/resource/m7ag-xvyh.csv?$li...
# 82   https://data.ny.gov/resource/vyyn-j8cu.csv?$li...
# 83   https://data.ny.gov/resource/qve8-dj3u.csv?$li...
# 84   https://data.ny.gov/resource/7wmq-pqff.csv?$li...
# 88   https://data.ny.gov/resource/3te2-xtd4.csv?$li...
# 91   https://data.ny.gov/resource/b5mc-nrji.csv?$li...
# 92   https://data.ny.gov/resource/7nhx-5bmg.csv?$li...
# 93   https://data.ny.gov/resource/kf6s-w5a7.csv?$li...
# 96   https://data.ny.gov/resource/wx2t-qtaz.csv?$li...
# 113  https://data.ny.gov/resource/jt9p-47ua.csv?$li...
# 114  https://data.ny.gov/resource/4qd6-ptxx.csv?$li...
# 115  https://data.ny.gov/resource/83hw-i6xw.csv?$li...
# 116  https://data.ny.gov/resource/sguy-yhj4.csv?$li...
# 121  https://data.ny.gov/resource/cy9b-i9w9.csv?$li...
# 122  https://data.ny.gov/resource/wrt8-4b59.csv?$li...
# 123  https://data.ny.gov/resource/swky-c3v4.csv?$li...
# 124  https://data.ny.gov/resource/2e6s-9gpm.csv?$li...
# 125  https://data.ny.gov/resource/bg59-42xi.csv?$li...
# 126  https://data.ny.gov/resource/j6d2-s8m2.csv?$li...
# 127  https://data.ny.gov/resource/6ksi-7cxr.csv?$li...
# 128  https://data.ny.gov/resource/4apg-4kt9.csv?$li...
# 129  https://data.ny.gov/resource/6b7q-snec.csv?$li...
# 130  https://data.ny.gov/resource/vtvh-gimj.csv?$li...

# %%
# Create a list of the unique values for the nys_url column where the catalog_category column contains the values "3. Accessibility".
urls = df2[df2['catalog_category'] == '3. Accessibility']['nys_url'].unique()

# %%
urls1 = df3[df3['catalog_category'] == '1. Operational metrics and data']['nys_url'].unique()

# %%
url = 'https://data.ny.gov/resource/rc78-7x78.csv'
response = requests.get(url)
buffer = StringIO(response.text)
df = pd.read_csv(buffer)

# %%
# create an empty dictionary to store the dataframes
dataframes1 = {}

# loop over the urls, skip any that don't work. For those that return 50000 rows, retrieve the next 50000 rows.
for url in urls1:
    try:
        response = requests.get(url)
        buffer = StringIO(response.text)
        df = pd.read_csv(buffer)
        dataframes1[url] = df
        while len(df) == 50000:
            url = url + '&$offset=50000'
            response = requests.get(url)
            buffer = StringIO(response.text)
            df = pd.read_csv(buffer)
            dataframes1[url] = df
    except: 
        pass

# %%
# create an empty dictionary to store the dataframes
dataframes1 = {}

# loop over the urls, skip any that don't work. For those that return 50000 rows, retrieve the next 50000 rows and append to the dataframe.
for url in urls1:
    try:
        response = requests.get(url)
        buffer = StringIO(response.text)
        df = pd.read_csv(buffer)
        dataframes1[url] = df
        while len(df) == 50000:
            url = url + '&$offset=50000'
            response = requests.get(url)
            buffer = StringIO(response.text)
            df1 = pd.read_csv(buffer)
            # append the dataframe to the existing dataframe using pandas.concat()
            df = pd.concat([df, df1])
            dataframes1[url] = df
    except:
        pass

# %%
urls1
# Out:
# array(['https://data.ny.gov/resource/ereg-mcvp.csv?$limit=50000',
#        'https://data.ny.gov/resource/x64c-i76x.csv?$limit=50000',
#        'https://data.ny.gov/resource/7mt2-y7ip.csv?$limit=50000',
#        'https://data.ny.gov/resource/e2qc-xgxs.csv?$limit=50000',
#        'https://data.ny.gov/resource/cpjs-d6ua.csv?$limit=50000',
#        'https://data.ny.gov/resource/32ch-sei3.csv?$limit=50000',
#        'https://data.ny.gov/resource/tw28-zvtk.csv?$limit=50000',
#        'https://data.ny.gov/resource/r7qk-6tcy.csv?$limit=50000',
#        'https://data.ny.gov/resource/8mkn-d32t.csv?$limit=50000',
#        'https://data.ny.gov/resource/cudb-vcni.csv?$limit=50000',
#        'https://data.ny.gov/resource/hpua-e653.csv?$limit=50000',
#        'https://data.ny.gov/resource/f6rf-2a3t.csv?$limit=50000',
#        'https://data.ny.gov/resource/6kq9-5ikh.csv?$limit=50000',
#        'https://data.ny.gov/resource/rube-svnv.csv?$limit=50000',
#        'https://data.ny.gov/Transportation/MTA-NYCT-Paratransit-Provider-No-Shows-Beginning-2/47iu-idvc.csv?$limit=50000',
#        'https://data.ny.gov/resource/qu52-5ejz.csv?$limit=50000',
#        'https://data.ny.gov/resource/s666-h6b7.csv?$limit=50000',
#        'https://data.ny.gov/resource/bmix-dpzc.csv?$limit=50000',
#        'https://data.ny.gov/resource/m7ag-xvyh.csv?$limit=50000',
#        'https://data.ny.gov/resource/vyyn-j8cu.csv?$limit=50000',
#        'https://data.ny.gov/resource/qve8-dj3u.csv?$limit=50000',
#        'https://data.ny.gov/resource/7wmq-pqff.csv?$limit=50000',
#        'https://data.ny.gov/resource/3te2-xtd4.csv?$limit=50000',
#        'https://data.ny.gov/resource/b5mc-nrji.csv?$limit=50000',
#        'https://data.ny.gov/resource/7nhx-5bmg.csv?$limit=50000',
#        'https://data.ny.gov/resource/kf6s-w5a7.csv?$limit=50000',
#        'https://data.ny.gov/resource/wx2t-qtaz.csv?$limit=50000',
#        'https://data.ny.gov/resource/jt9p-47ua.csv?$limit=50000',
#        'https://data.ny.gov/resource/4qd6-ptxx.csv?$limit=50000',
#        'https://data.ny.gov/resource/83hw-i6xw.csv?$limit=50000',
#        'https://data.ny.gov/resource/sguy-yhj4.csv?$limit=50000',
#        'https://data.ny.gov/resource/cy9b-i9w9.csv?$limit=50000',
#        'https://data.ny.gov/resource/wrt8-4b59.csv?$limit=50000',
#        'https://data.ny.gov/resource/swky-c3v4.csv?$limit=50000',
#        'https://data.ny.gov/resource/2e6s-9gpm.csv?$limit=50000',
#        'https://data.ny.gov/resource/bg59-42xi.csv?$limit=50000',
#        'https://data.ny.gov/resource/j6d2-s8m2.csv?$limit=50000',
#        'https://data.ny.gov/resource/6ksi-7cxr.csv?$limit=50000',
#        'https://data.ny.gov/resource/4apg-4kt9.csv?$limit=50000',
#        'https://data.ny.gov/resource/6b7q-snec.csv?$limit=50000',
#        'https://data.ny.gov/resource/vtvh-gimj.csv?$limit=50000'],
#       dtype=object)

# %%
# create an empty dictionary to store the dataframes
#dataframes1 = {}

# loop over the nys_url column of df2 and if the returned records are equal to 50000, request the next 50000 records
#for url in urls1:
    # Use requests to get the contents
    response = requests.get(url)
    # Use io.StringIO to get a file-like object, store in buffer
    buffer = io.StringIO(response.content.decode())
    # option 2: use io.BytesIO to get a file-like object
    df = pd.read_csv(buffer)
    # store the dataframe in the dictionary with the url as the key
    dataframes1[url] = df
# Out:
#   Cell In[22], line 7
#     response = requests.get(url)
#     ^
# IndentationError: unexpected indent

# %%
# view the first 5 rows of the dataframe for each key in the dictionary
for key in dataframes.keys():
    print(key)
    print(dataframes[key].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # view the first 5 rows of the dataframe for each key in the dictionary
# ----> 2 for key in dataframes.keys():
#       3     print(key)
#       4     print(dataframes[key].head())
#
# NameError: name 'dataframes' is not defined

# %%
# Print the shape of the dataframe for each key in the dictionary
for key in dataframes1.keys():
    print(key)
    print(dataframes1[key].shape)
# Out:
# https://data.ny.gov/resource/ereg-mcvp.csv?$limit=50000
# (3440, 6)
# https://data.ny.gov/resource/x64c-i76x.csv?$limit=50000
# (103, 7)
# https://data.ny.gov/resource/7mt2-y7ip.csv?$limit=50000
# (515, 5)
# https://data.ny.gov/resource/e2qc-xgxs.csv?$limit=50000
# (1626, 7)
# https://data.ny.gov/resource/cpjs-d6ua.csv?$limit=50000
# (758, 6)
# https://data.ny.gov/resource/32ch-sei3.csv?$limit=50000
# (2849, 7)
# https://data.ny.gov/resource/tw28-zvtk.csv?$limit=50000
# (34918, 9)
# https://data.ny.gov/resource/r7qk-6tcy.csv?$limit=50000
# (2108, 12)
# https://data.ny.gov/resource/8mkn-d32t.csv?$limit=50000
# (18753, 9)
# https://data.ny.gov/resource/cudb-vcni.csv?$limit=50000
# (50000, 9)
# https://data.ny.gov/resource/cudb-vcni.csv?$limit=50000&$offset=50000
# (67962, 9)
# https://data.ny.gov/resource/hpua-e653.csv?$limit=50000
# (668, 6)
# https://data.ny.gov/resource/f6rf-2a3t.csv?$limit=50000
# (1665, 7)
# https://data.ny.gov/resource/6kq9-5ikh.csv?$limit=50000
# (1232, 6)
# https://data.ny.gov/resource/rube-svnv.csv?$limit=50000
# (50000, 8)
# https://data.ny.gov/resource/rube-svnv.csv?$limit=50000&$offset=50000
# (100000, 8)
# https://data.ny.gov/resource/qu52-5ejz.csv?$limit=50000
# (40, 5)
# https://data.ny.gov/resource/s666-h6b7.csv?$limit=50000
# (5590, 8)
# https://data.ny.gov/resource/bmix-dpzc.csv?$limit=50000
# (50000, 9)
# https://data.ny.gov/resource/bmix-dpzc.csv?$limit=50000&$offset=50000
# (69275, 9)
# https://data.ny.gov/resource/m7ag-xvyh.csv?$limit=50000
# (477, 6)
# https://data.ny.gov/resource/vyyn-j8cu.csv?$limit=50000
# (1362, 5)
# https://data.ny.gov/resource/qve8-dj3u.csv?$limit=50000
# (1362, 5)
# https://data.ny.gov/resource/7wmq-pqff.csv?$limit=50000
# (990, 3)
# https://data.ny.gov/resource/3te2-xtd4.csv?$limit=50000
# (116, 3)
# https://data.ny.gov/resource/b5mc-nrji.csv?$limit=50000
# (515, 5)
# https://data.ny.gov/resource/7nhx-5bmg.csv?$limit=50000
# (404, 6)
# https://data.ny.gov/resource/kf6s-w5a7.csv?$limit=50000
# (204, 5)
# https://data.ny.gov/resource/wx2t-qtaz.csv?$limit=50000
# (29073, 7)
# https://data.ny.gov/resource/jt9p-47ua.csv?$limit=50000
# (385, 7)
# https://data.ny.gov/resource/4qd6-ptxx.csv?$limit=50000
# (168, 7)
# https://data.ny.gov/resource/83hw-i6xw.csv?$limit=50000
# (301, 6)
# https://data.ny.gov/resource/sguy-yhj4.csv?$limit=50000
# (86, 7)
# https://data.ny.gov/resource/cy9b-i9w9.csv?$limit=50000
# (15991, 17)
# https://data.ny.gov/resource/wrt8-4b59.csv?$limit=50000
# (25635, 9)
# https://data.ny.gov/resource/swky-c3v4.csv?$limit=50000
# (49752, 9)
# https://data.ny.gov/resource/2e6s-9gpm.csv?$limit=50000
# (24988, 9)
# https://data.ny.gov/resource/bg59-42xi.csv?$limit=50000
# (2034, 7)
# https://data.ny.gov/resource/j6d2-s8m2.csv?$limit=50000
# (1668, 6)
# https://data.ny.gov/resource/6ksi-7cxr.csv?$limit=50000
# (48397, 9)
# https://data.ny.gov/resource/4apg-4kt9.csv?$limit=50000
# (2083, 12)
# https://data.ny.gov/resource/6b7q-snec.csv?$limit=50000
# (4008, 8)
# https://data.ny.gov/resource/vtvh-gimj.csv?$limit=50000
# (2007, 7)

# %%
# print the column names for each key in the dictionary
for key in dataframes1.keys():
    print(key)
    print(dataframes1[key].columns)
# Out:
# https://data.ny.gov/resource/ereg-mcvp.csv?$limit=50000
# Index(['month', 'division', 'line', 'day_type', 'category', 'count'], dtype='object')
# https://data.ny.gov/resource/x64c-i76x.csv?$limit=50000
# Index(['month', 'majorincidents', '_4mto6mtraindelays', 'avgdelayperlatetrain',
#        'nooftrainsover15minslate', 'noofshorttrains', 'lirrlowadhesiondelays'],
#       dtype='object')
# https://data.ny.gov/resource/7mt2-y7ip.csv?$limit=50000
# Index(['month', 'borough', 'monthly_miles', 'monthly_road_call_count',
#        'monthly_mdbf'],
#       dtype='object')
# https://data.ny.gov/resource/e2qc-xgxs.csv?$limit=50000
# Index(['month', 'car_class', 'mdbf', 'mdbf_12avg', 'total_miles',
#        'number_of_failures', 'number_of_cars'],
#       dtype='object')
# https://data.ny.gov/resource/cpjs-d6ua.csv?$limit=50000
# Index(['month', 'fleettype', 'mdbfvalue', 'fleet_owned',
#        'no_of_primary_failures', 'mdbf_goal'],
#       dtype='object')
# https://data.ny.gov/resource/32ch-sei3.csv?$limit=50000
# Index(['month', 'division', 'line', 'day_type', 'num_sched_trains',
#        'num_actual_trains', 'service_delivered'],
#       dtype='object')
# https://data.ny.gov/resource/tw28-zvtk.csv?$limit=50000
# Index(['month', 'borough', 'day_type', 'trip_type', 'route_id', 'period',
#        'actual_number_of_buses', 'scheduled_number_of_buses',
#        'service_delivered'],
#       dtype='object')
# https://data.ny.gov/resource/r7qk-6tcy.csv?$limit=50000
# Index(['month', 'division', 'line', 'period', 'num_passengers',
#        'additional_platform_time', 'additional_train_time', 'total_apt',
#        'total_att', 'over_five_mins', 'over_five_mins_perc',
#        'customer_journey_time'],
#       dtype='object')
# https://data.ny.gov/resource/8mkn-d32t.csv?$limit=50000
# Index(['month', 'borough', 'trip_type', 'route_id', 'period',
#        'number_of_customers', 'additional_bus_stop_time',
#        'additional_travel_time', 'customer_journey_time'],
#       dtype='object')
# https://data.ny.gov/resource/cudb-vcni.csv?$limit=50000
# Index(['month', 'borough', 'day_type', 'trip_type', 'route_id', 'period',
#        'total_operating_time', 'total_mileage', 'average_speed'],
#       dtype='object')
# https://data.ny.gov/resource/hpua-e653.csv?$limit=50000
# Index(['month', 'line', 'actual', 'scheduled', 'cancelled', 'terminated'], dtype='object')
# https://data.ny.gov/resource/f6rf-2a3t.csv?$limit=50000
# Index(['month', 'line', 'division', 'day_type', 'num_on_time_trips',
#        'num_sched_trips', 'terminal_on_time_performance'],
#       dtype='object')
# https://data.ny.gov/resource/6kq9-5ikh.csv?$limit=50000
# Index(['month', 'branch_line', 'otp', 'am_peak', 'pm_peak', 'off_peak'], dtype='object')
# https://data.ny.gov/resource/rube-svnv.csv?$limit=50000
# Index(['date', 'hour_of_promise_time', 'provider_type', 'stanrdard',
#        'on_time_performance', 'pickup_location', 'total_pickups',
#        'pickups_within_standards'],
#       dtype='object')
# https://data.ny.gov/resource/qu52-5ejz.csv?$limit=50000
# Index(['servicedate', 'month', 'year', 'provider_type',
#        'experiencepercentage'],
#       dtype='object')
# https://data.ny.gov/resource/s666-h6b7.csv?$limit=50000
# Index(['month', 'line', 'division', 'day_type', 'period',
#        'num_timepoints_passing_wait_assessment', 'num_sched_timepoints',
#        'wait_assessment'],
#       dtype='object')
# https://data.ny.gov/resource/bmix-dpzc.csv?$limit=50000
# Index(['month', 'borough', 'day_type', 'trip_type', 'route_id', 'period',
#        'number_of_trips_passing_wait', 'number_of_scheduled_trips',
#        'wait_assessment'],
#       dtype='object')
# https://data.ny.gov/resource/m7ag-xvyh.csv?$limit=50000
# Index(['month', 'borough', 'trip_type', 'appearance_score',
#        'information_score', 'equipment_score'],
#       dtype='object')
# https://data.ny.gov/resource/vyyn-j8cu.csv?$limit=50000
# Index(['month', 'line', 'appearance_score', 'equipment_score',
#        'information_score'],
#       dtype='object')
# https://data.ny.gov/resource/qve8-dj3u.csv?$limit=50000
# Index(['month', 'line', 'appearance_score', 'equipment_score',
#        'information_score'],
#       dtype='object')
# https://data.ny.gov/resource/7wmq-pqff.csv?$limit=50000
# Index(['servicedate', 'delaycategory', 'nooftrains'], dtype='object')
# https://data.ny.gov/resource/3te2-xtd4.csv?$limit=50000
# Index(['month', 'provider_type', 'perfomance'], dtype='object')
# https://data.ny.gov/resource/b5mc-nrji.csv?$limit=50000
# Index(['month', 'borough', 'monthly_miles', 'monthly_road_call_count',
#        'monthly_mdbsi'],
#       dtype='object')
# https://data.ny.gov/resource/7nhx-5bmg.csv?$limit=50000
# Index(['month', 'am_pm', 'company', 'scheduled_buses', 'operating_buses',
#        'monthly_pull_out'],
#       dtype='object')
# https://data.ny.gov/resource/kf6s-w5a7.csv?$limit=50000
# Index(['month', 'company', 'fleet_age', 'total_of_buses',
#        '_of_buses_over_12_years'],
#       dtype='object')
# https://data.ny.gov/resource/wx2t-qtaz.csv?$limit=50000
# Index(['month', 'subdivison', 'line', 'day_type', 'reporting_category',
#        'subcategory', 'delays'],
#       dtype='object')
# https://data.ny.gov/resource/jt9p-47ua.csv?$limit=50000
# Index(['month', 'service_territory', 'line', 'actual', 'scheduled',
#        'cancelled', 'terminated'],
#       dtype='object')
# https://data.ny.gov/resource/4qd6-ptxx.csv?$limit=50000
# Index(['month', 'fleet_type', 'mdbf_value', 'fleet_owned',
#        'no_of_primary_failures', 'mdbf_goal', 'no_of_primary_failures_goal'],
#       dtype='object')
# https://data.ny.gov/resource/83hw-i6xw.csv?$limit=50000
# Index(['month', 'branch_line', 'otp', 'am_peak', 'pm_peak', 'off_peak'], dtype='object')
# https://data.ny.gov/resource/sguy-yhj4.csv?$limit=50000
# Index(['month', 'service_territory', 'majorincidents', '_4mto6mtraindelays',
#        'avgdelayperlatetrain', 'nooftrainsover15minslate', 'noofshorttrains'],
#       dtype='object')
# https://data.ny.gov/resource/cy9b-i9w9.csv?$limit=50000
# Index(['indicator_sequence', 'parent_sequence', 'agency_name',
#        'indicator_name', 'description', 'category', 'frequency',
#        'desired_change', 'indicator_unit', 'decimal_places', 'period_year',
#        'period_month', 'ytd_target', 'ytd_actual', 'monthly_target',
#        'monthly_actual', 'period'],
#       dtype='object')
# https://data.ny.gov/resource/wrt8-4b59.csv?$limit=50000
# Index(['month', 'borough', 'trip_type', 'route_id', 'period',
#        'number_of_customers', 'additional_bus_stop_time',
#        'additional_travel_time', 'customer_journey_time'],
#       dtype='object')
# https://data.ny.gov/resource/swky-c3v4.csv?$limit=50000
# Index(['month', 'borough', 'day_type', 'trip_type', 'route_id', 'period',
#        'number_of_trips_passing_wait', 'number_of_scheduled_trips',
#        'wait_assessment'],
#       dtype='object')
# https://data.ny.gov/resource/2e6s-9gpm.csv?$limit=50000
# Index(['month', 'borough', 'day_type', 'trip_type', 'route_id', 'period',
#        'actual_number_of_buses', 'scheduled_number_of_buses',
#        'service_delivered'],
#       dtype='object')
# https://data.ny.gov/resource/bg59-42xi.csv?$limit=50000
# Index(['month', 'division', 'line', 'day_type', 'num_sched_trains',
#        'num_actual_trains', 'service_delivered'],
#       dtype='object')
# https://data.ny.gov/resource/j6d2-s8m2.csv?$limit=50000
# Index(['month', 'division', 'line', 'day_type', 'category', 'count'], dtype='object')
# https://data.ny.gov/resource/6ksi-7cxr.csv?$limit=50000
# Index(['month', 'borough', 'day_type', 'trip_type', 'route_id', 'period',
#        'total_mileage', 'total_operating_time', 'average_speed'],
#       dtype='object')
# https://data.ny.gov/resource/4apg-4kt9.csv?$limit=50000
# Index(['month', 'division', 'line', 'period', 'num_passengers',
#        'additional_platform_time', 'additional_train_time', 'total_apt',
#        'total_att', 'over_five_mins', 'over_five_mins_perc',
#        'customer_journey_time'],
#       dtype='object')
# https://data.ny.gov/resource/6b7q-snec.csv?$limit=50000
# Index(['month', 'division', 'line', 'day_type', 'period',
#        'num_timepoints_passing_wait', 'num_sched_timepoints',
#        'wait_assessment'],
#       dtype='object')
# https://data.ny.gov/resource/vtvh-gimj.csv?$limit=50000
# Index(['month', 'division', 'line', 'day_type', 'num_on_time_trips',
#        'num_sched_trips', 'terminal_on_time_performance'],
#       dtype='object')
